# %% [markdown]
# <a href="https://colab.research.google.com/github/angel870326/NTU_Capstone/blob/main/activity_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > 2022.05.10 Ssu-Yun Wang<br/>
# [Github @angel870326](https://github.com/angel870326)
#
# # **看過去辦的活動都是辦在哪一群**
#
# #### **Contents:**
#
# New Taipei
# *   Functions
# *   Ward 3
# *   Add cluster ID column
#
# Taipei
# *   Ward 3
# *   Add cluster ID column

# %%
import pandas as pd
import numpy as np

# %%
# sConnect to the Google Drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## **New Taipei**

# %%
activity_newtaipei = pd.read_excel('/content/gdrive/Shareddrives/110-2 Capstone/社區活動/社區活動特徵結果/activity_concat_newtaipei.xlsx')
cluster_newtaipei = pd.read_csv('/content/gdrive/MyDrive/碩一下/Capstone/hierarchical_clustering/taipei/hierarchical_textcluster_newtaipei.csv')

# Number of observations and variables
print("活動資料檔 (activity)：", activity_newtaipei.shape)
print("分群結果檔 (cluster)： ", cluster_newtaipei.shape)
# Out:
# 活動資料檔 (activity)： (9210, 25)
# 分群結果檔 (cluster)：  (5051, 18)

# %% [markdown]
# ### Functions

# %%
# Array of building IDs for a cluster
def clusterFilterArray(cluster_city, method, clusterID):
  filter = cluster_city[method].isin([clusterID])
  method_clusterID = cluster_city.loc[filter,['c0101',method]]
  print(method, "-", clusterID, ":", method_clusterID.shape) # Number of observations and variables for a cluster
  return method_clusterID.c0101.to_numpy()

# Activities in a cluster
def activityInCluster(activity_city, cluster_buildingIDs):
  filter = activity_city['c0116'].isin(cluster_buildingIDs)
  nt_activity_method_cluster = activity_city.loc[filter,:]
  return nt_activity_method_cluster

# %% [markdown]
# ### Ward 3

# %%
# Create an array of building IDs for each cluster
print("各群建物數 (number of buildings in a cluster)：")
nt_ward_3_1_filter = clusterFilterArray(cluster_newtaipei,'cluster_ward_3',1)
nt_ward_3_2_filter = clusterFilterArray(cluster_newtaipei,'cluster_ward_3',2)
nt_ward_3_3_filter = clusterFilterArray(cluster_newtaipei,'cluster_ward_3',3)

print("\nExample array:", nt_ward_3_1_filter)
# Out:
# 各群建物數 (number of buildings in a cluster)：
# cluster_ward_3 - 1 : (2254, 2)
# cluster_ward_3 - 2 : (1935, 2)
# cluster_ward_3 - 3 : (862, 2)
#
# Example array: ['0000001' '0000008' '0000011' ... 'Y001224' 'Y001233' 'Y001237']

# %%
# Find the activities held for each cluster
print("各群過去幾年辦的活動數：")
# Cluster 1
nt_activity_ward_3_1 = activityInCluster(activity_newtaipei, nt_ward_3_1_filter)
print(nt_activity_ward_3_1.shape) # Number of observations and variables
# Cluster 2
nt_activity_ward_3_2 = activityInCluster(activity_newtaipei, nt_ward_3_2_filter)
print(nt_activity_ward_3_2.shape) # Number of observations and variables
# Cluster 3
nt_activity_ward_3_3 = activityInCluster(activity_newtaipei, nt_ward_3_3_filter)
print(nt_activity_ward_3_3.shape) # Number of observations and variables
# Out:
# 各群過去幾年辦的活動數：
# (1359, 25)
# (6432, 25)
# (1419, 25)

# %% [markdown]
# ### Add cluster ID column

# %%
nt_activity_ward_3_1['text_ward_3'] = '1'
nt_activity_ward_3_2['text_ward_3'] = '2'
nt_activity_ward_3_3['text_ward_3'] = '3'
nt_activity = pd.concat([nt_activity_ward_3_1, nt_activity_ward_3_2, nt_activity_ward_3_3])
print(nt_activity.shape) # Number of observations and variables
nt_activity
# Out:
# (9210, 26)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
nt_activity.to_excel("/content/gdrive/MyDrive/碩一下/Capstone/社區活動/activity_concat_newtaipei.xlsx", index=False)
nt_activity.to_excel("/content/gdrive/Shareddrives/110-2 Capstone/社區活動/社區活動特徵結果/activity_concat_newtaipei.xlsx", index=False)

# %% [markdown]
# ## **Taipei**

# %%
activity_taipei = pd.read_excel('/content/gdrive/Shareddrives/110-2 Capstone/社區活動/社區活動特徵結果/activity_concat_taipei.xlsx')
cluster_taipei = pd.read_csv('/content/gdrive/MyDrive/碩一下/Capstone/hierarchical_clustering/taipei/hierarchical_textcluster_taipei.csv')

# Number of observations and variables
print("活動資料檔 (activity)：", activity_taipei.shape)
print("分群結果檔 (cluster)： ", cluster_taipei.shape)
# Out:
# 活動資料檔 (activity)： (6249, 25)
# 分群結果檔 (cluster)：  (5554, 18)

# %% [markdown]
# ### Ward 3

# %%
# Create an array of building IDs for each cluster
print("各群建物數 (number of buildings in a cluster)：")
t_ward_3_1_filter = clusterFilterArray(cluster_taipei,'cluster_ward_3',1)
t_ward_3_2_filter = clusterFilterArray(cluster_taipei,'cluster_ward_3',2)
t_ward_3_3_filter = clusterFilterArray(cluster_taipei,'cluster_ward_3',3)

print("\nExample array:", t_ward_3_1_filter)
# Out:
# 各群建物數 (number of buildings in a cluster)：
# cluster_ward_3 - 1 : (2554, 2)
# cluster_ward_3 - 2 : (1564, 2)
# cluster_ward_3 - 3 : (1436, 2)
#
# Example array: ['0000251' '0000252' '0000254' ... 'Y001264' 'Y001265' 'Y001273']

# %%
# Find the activities held for each cluster
print("各群過去幾年辦的活動數：")
# Cluster 1
t_activity_ward_3_1 = activityInCluster(activity_taipei, t_ward_3_1_filter)
print(t_activity_ward_3_1.shape) # Number of observations and variables
# Cluster 2
t_activity_ward_3_2 = activityInCluster(activity_taipei, t_ward_3_2_filter)
print(t_activity_ward_3_2.shape) # Number of observations and variables
# Cluster 3
t_activity_ward_3_3 = activityInCluster(activity_taipei, t_ward_3_3_filter)
print(t_activity_ward_3_3.shape) # Number of observations and variables
# Out:
# 各群過去幾年辦的活動數：
# (4393, 25)
# (329, 25)
# (1527, 25)

# %% [markdown]
# ### Add cluster ID column

# %%
t_activity_ward_3_1['text_ward_3'] = '1'
t_activity_ward_3_2['text_ward_3'] = '2'
t_activity_ward_3_3['text_ward_3'] = '3'
t_activity = pd.concat([t_activity_ward_3_1, t_activity_ward_3_2, t_activity_ward_3_3])
print(t_activity.shape) # Number of observations and variables
t_activity
# Out:
# (6249, 26)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
t_activity.to_excel("/content/gdrive/MyDrive/碩一下/Capstone/社區活動/activity_concat_taipei.xlsx", index=False)
t_activity.to_excel("/content/gdrive/Shareddrives/110-2 Capstone/社區活動/社區活動特徵結果/activity_concat_taipei.xlsx", index=False)
